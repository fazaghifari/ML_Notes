# %% [markdown]
# # Classification Algorithm
#
# **Goal**
# - Able to classify something.
# - Given the features of "that thing"
# - For example:
#     - If a person has several symptoms such as sore throat, sneezing, and fever. Is he/she sick or not?
#     - If a house has a swimming pool, 5 bedrooms, 2 bathrooms, and 1 kitchen. Is it a luxury house or not?
#     - etc
# - Here's some visual example.
#     - Given a dataset.
#     - The dataset has features: Credit card balance of each person, the Income of each person and the status if _default_ or not.
#
# ![image.png](attachment:b06859a6-3974-47fc-a27e-76b736c75f42.png)
